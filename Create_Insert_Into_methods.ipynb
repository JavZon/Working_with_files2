# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Working_with_files2/blob/main/Create_Insert_Into_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sqlite3 as sql

# %%
python="""Hello world
this is a test
but we will
see the result"""
print(python)
# Out:
# Hello world
# this is a test
# but we will
# see the result

# %%
db=sql.connect('my_data_base.db')

# %%
cursor=db.cursor()

# %%
dict1={
    'A':[14,53,78,9,21],
    'B':[133,99,70,55,8],
    'C':[34,89,66,75,22]
}
df=pd.DataFrame(dict1)
df
# Out:
#     A    B   C
# 0  14  133  34
# 1  53   99  89
# 2  78   70  66
# 3   9   55  75
# 4  21    8  22

# %%
df.to_sql('Alphabet',db)
# Out:
# 5

# %%
query="SELECT name FROM sqlite_master WHERE type='table';"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('Alphabet',)]

# %%
query="PRAGMA table_info(Alphabet)"
cursor.execute(query)
cursor.fetchall()
# Out:
# [(0, 'index', 'INTEGER', 0, None, 0),
#  (1, 'A', 'INTEGER', 0, None, 0),
#  (2, 'B', 'INTEGER', 0, None, 0),
#  (3, 'C', 'INTEGER', 0, None, 0)]

# %%
pd.read_sql("SELECT * FROM Alphabet WHERE A>10 ORDER BY C",db, index_col='index')
# Out:
#         A    B   C
# index
# 4      21    8  22
# 0      14  133  34
# 2      78   70  66
# 1      53   99  89

# %%
query="""
CREATE TABLE IF NOT EXISTS Students(
  student_id INT PRIMARY KEY NOT NULL,
  name TEXT NOT NULL,
  age INT NOT NULL,
  course INT,
  grade TEXT NOT NULL
);
"""
cursor.execute(query)
db.commit()

# %%
query="SELECT name FROM sqlite_master WHERE type='table';"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('Alphabet',), ('Students',)]

# %%
query="PRAGMA table_info(Alphabet)"
cursor.execute(query)
cursor.fetchall()
# Out:
# [(0, 'index', 'INTEGER', 0, None, 0),
#  (1, 'A', 'INTEGER', 0, None, 0),
#  (2, 'B', 'INTEGER', 0, None, 0),
#  (3, 'C', 'INTEGER', 0, None, 0)]

# %%
query="PRAGMA table_info(Students)"
cursor.execute(query)
cursor.fetchall()
# Out:
# [(0, 'student_id', 'INT', 1, None, 1),
#  (1, 'name', 'TEXT', 1, None, 0),
#  (2, 'age', 'INT', 1, None, 0),
#  (3, 'course', 'INT', 0, None, 0),
#  (4, 'grade', 'TEXT', 1, None, 0)]

# %%
query="""
INSERT INTO Students VALUES(
  1,'John',25,2,'B+');
  """
cursor.execute(query)
db.commit()

# %%
q="SELECT * FROM Students"
cursor.execute(q)
cursor.fetchall()
# Out:
# [(1, 'John', 25, 2, 'B+')]

# %%
query="""
INSERT INTO Students VALUES(
  2,'Maya',28,4,'A-');
  """
cursor.execute(query)
db.commit()

# %%
q="SELECT * FROM Students"
cursor.execute(q)
cursor.fetchall()
# Out:
# [(1, 'John', 25, 2, 'B+'), (2, 'Maya', 28, 4, 'A-')]

# %%
pd.read_sql(q,db)
# Out:
#    student_id  name  age  course grade
# 0           1  John   25       2    B+
# 1           2  Maya   28       4    A-
