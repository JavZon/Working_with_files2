# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Working_with_files2/blob/main/Untitled39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
a=[32,56,13,9, 6.8, 5.7, 44.61, 12.8]
e=[0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.65]
np.random.choice(a, p=e)
# Out:
# 12.8

# %%
link='https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population.csv'
df=pd.read_csv(link)
df.head()
# Out:
#    rank    country     density   densityMi   pop2021  area
# 0     1      Macau  21946.4667  56841.3487   658.394    30
# 1     2     Monaco  19755.5000  51166.7450    39.511     2
# 2     3  Singapore   8305.1915  21510.4461  5896.686   710
# 3     4  Hong Kong   6841.3134  17719.0017  7552.810  1104
# 4     5  Gibraltar   5616.3333  14546.3033    33.698     6

# %%
df=pd.read_csv(link, index_col=1)
df.head(7)
df.drop(columns='rank')
# Out:
#                      density   densityMi   pop2021     area
# country
# Macau             21946.4667  56841.3487   658.394       30
# Monaco            19755.5000  51166.7450    39.511        2
# Singapore          8305.1915  21510.4461  5896.686      710
# Hong Kong          6841.3134  17719.0017  7552.810     1104
# Gibraltar          5616.3333  14546.3033    33.698        6
# ...                      ...         ...       ...      ...
# Namibia               3.1338      8.1166  2587.344   825615
# Western Sahara        2.3003      5.9577   611.875   266000
# Mongolia              2.1286      5.5129  3329.289  1564110
# Falkland Islands      0.2902      0.7517     3.533    12173
# Greenland             0.0263      0.0680    56.877  2166086
#
# [232 rows x 4 columns]

# %%
df=pd.read_csv(link, usecols=['area','pop2021','density'])
df.head(6)
# Out:
#       density   pop2021  area
# 0  21946.4667   658.394    30
# 1  19755.5000    39.511     2
# 2   8305.1915  5896.686   710
# 3   6841.3134  7552.810  1104
# 4   5616.3333    33.698     6
# 5   2285.3542  1748.296   765

# %%
df=pd.read_csv(link, usecols=[1,2,5])
df.head(6)
# Out:
#      country     density  area
# 0      Macau  21946.4667    30
# 1     Monaco  19755.5000     2
# 2  Singapore   8305.1915   710
# 3  Hong Kong   6841.3134  1104
# 4  Gibraltar   5616.3333     6
# 5    Bahrain   2285.3542   765

# %%
df2=pd.read_excel('/content/uzbekistan (3).xlsx', index_col=0, names=['municipiality','area','population'])
df2
# Out:
#                                  area  population
# municipiality
# Andijon viloyati                 4200     1899000
# Buxoro viloyati                 39400     1384700
# Fargʻona viloyati                6800     2597000
# Jizzax viloyati                 20500      910500
# Xorazm viloyati                  6300     1200000
# Namangan viloyati                7900     1862000
# Navoiy viloyati                110800      767500
# Qashqadaryo viloyati            28400     2029000
# Qoraqalpogʻiston Respublikasi  160000     1200000
# Samarqand viloyati              16400     2322000
# Sirdaryo viloyati                5100      648100
# Surxondaryo viloyati            20800     1676000
# Toshkent viloyati               15300     4450000

# %%
df2.columns
df2.index.name
# Out:
# 'Boʻlinishi'

# %%
df=pd.read_csv(link,index_col='rank')
df.describe()
# Out:
#             density     densityMi       pop2021          area
# count    232.000000    232.000000  2.320000e+02  2.320000e+02
# mean     450.585827   1167.017293  3.394292e+04  5.864610e+05
# std     2078.591351   5383.551600  1.368881e+05  1.768617e+06
# min        0.026300      0.068000  8.000000e-01  1.000000e+00
# 25%       35.442775     91.796750  4.424710e+02  3.735250e+03
# 50%       95.418750    247.134600  5.602686e+03  8.356700e+04
# 75%      240.029700    621.676950  2.149715e+04  4.403752e+05
# max    21946.466700  56841.348700  1.444216e+06  1.709824e+07

# %%
import numpy as np
import pandas as pd

# %%
dict1={
    'Name':['John','Meta','LPG'],
    'Year':[1992,2003,1968],
    'Salary':[15000,23000,9800]
}
df1=pd.DataFrame(dict1, index=['i1','i2','i3'])
df1
# Out:
#     Name  Year  Salary
# i1  John  1992   15000
# i2  Meta  2003   23000
# i3   LPG  1968    9800

# %%
df1.to_csv('new_dict1')

# %%
new_df=pd.read_csv('/content/new_dict1', index_col=0)
new_df
# Out:
#     Name  Year  Salary
# i1  John  1992   15000
# i2  Meta  2003   23000
# i3   LPG  1968    9800

# %%
df=pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv', index_col='index')
df.head(2)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0

# %%
df3=df.iloc[0:11,[0,1,8]]
df3.to_excel('new_car.xlsx', index=False)

# %%
df4=pd.read_excel('/content/new_car.xlsx', names=['qumpani','tana','narx'])
df4.groupby('qumpani')[['narx']].mean()
# Out:
#                      narx
# qumpani
# alfa-romero  15498.333333
# audi         16392.500000
# bmw          21271.250000

# %%
# Out:
#   File "<ipython-input-76-b90341000f29>", line 1
#     print("HHH"'''",mmm")
#                ^
# SyntaxError: incomplete input

# %%
df2=pd.read_excel('/content/uzbekistan (3).xlsx',)
df2.sort_values(by="Boʻlinishi")

df2.loc[0:5,["Boʻlinishi",'Aholisi']]
df2['Aholisi'].mean()
maska=df2['Aholisi']>1300000
maska
df2[maska]
# Out:
#               Boʻlinishi  Maydoni (kv.km)  Aholisi
# 0       Andijon viloyati             4200  1899000
# 1        Buxoro viloyati            39400  1384700
# 2      Fargʻona viloyati             6800  2597000
# 5      Namangan viloyati             7900  1862000
# 7   Qashqadaryo viloyati            28400  2029000
# 9     Samarqand viloyati            16400  2322000
# 11  Surxondaryo viloyati            20800  1676000
# 12     Toshkent viloyati            15300  4450000

# %%
df2.at[2,'Maydoni (kv.km)']
# Out:
# 6800
