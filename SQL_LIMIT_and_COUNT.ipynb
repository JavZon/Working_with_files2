# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Working_with_files2/blob/main/SQL_LIMIT_and_COUNT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3 as sql
import pandas as pd
import numpy as np

# %%
# !wget https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Out:
# --2024-03-03 00:26:34--  https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Resolving www.sqlitetutorial.net (www.sqlitetutorial.net)... 172.67.172.250, 104.21.30.141, 2606:4700:3037::6815:1e8d, ...
# Connecting to www.sqlitetutorial.net (www.sqlitetutorial.net)|172.67.172.250|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305596 (298K) [application/zip]
# Saving to: ‘chinook.zip.1’
#
# chinook.zip.1       100%[===================>] 298.43K  --.-KB/s    in 0.09s
#
# 2024-03-03 00:26:35 (3.20 MB/s) - ‘chinook.zip.1’ saved [305596/305596]

# %%
# !unzip chinook.zip
# Out:
# Archive:  chinook.zip
#   inflating: chinook.db

# %%
db=sql.connect('chinook.db')

# %%
cursor=db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type= 'table' ; ")
cursor.fetchall()
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
cursor.execute("SELECT COUNT (*) FROM sqlite_stat1")
cursor.fetchall()
# Out:
# [(15,)]

# %%
cursor.execute("SELECT * FROM media_types")
cursor.fetchall()
# Out:
# [(1, 'MPEG audio file'),
#  (2, 'Protected AAC audio file'),
#  (3, 'Protected MPEG-4 video file'),
#  (4, 'Purchased AAC audio file'),
#  (5, 'AAC audio file')]

# %%
cursor.execute("SELECT * FROM media_types")
cursor.fetchall()
# Out:
# [(1, 'MPEG audio file'),
#  (2, 'Protected AAC audio file'),
#  (3, 'Protected MPEG-4 video file'),
#  (4, 'Purchased AAC audio file'),
#  (5, 'AAC audio file')]

# %%
query="SELECT * FROM media_types"
df=pd.read_sql(query, db)
df
# Out:
#    MediaTypeId                         Name
# 0            1              MPEG audio file
# 1            2     Protected AAC audio file
# 2            3  Protected MPEG-4 video file
# 3            4     Purchased AAC audio file
# 4            5               AAC audio file

# %%
query="SELECT * FROM media_types"
df=pd.read_sql(query, db, index_col='MediaTypeId')
df
# Out:
#                                     Name
# MediaTypeId
# 1                        MPEG audio file
# 2               Protected AAC audio file
# 3            Protected MPEG-4 video file
# 4               Purchased AAC audio file
# 5                         AAC audio file

# %%
cursor.execute("PRAGMA table_info(sqlite_stat1)")
cursor.fetchall()
# Out:
# [(0, 'tbl', '', 0, None, 0),
#  (1, 'idx', '', 0, None, 0),
#  (2, 'stat', '', 0, None, 0)]

# %%
query="SELECT * FROM sqlite_stat1"
df2=pd.read_sql(query, db)
df2.iloc[:6, [1,2]]
# Out:
#                                  idx        stat
# 0               IFK_TrackMediaTypeId    3503 701
# 1                   IFK_TrackGenreId    3503 141
# 2                   IFK_TrackAlbumId     3503 11
# 3           IFK_PlaylistTrackTrackId      8715 3
# 4  sqlite_autoindex_playlist_track_1  8715 623 1
# 5                  IFK_AlbumArtistId       347 2

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type= 'table' ; ")
cursor.fetchall()
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
cursor.execute("SELECT COUNT(*) FROM employees")
cursor.fetchall()
# Out:
# [(8,)]

# %%
query="SELECT * FROM employees"
df3=pd.read_sql(query,db)
df3
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %%
query="SELECT LastName, FirstName, Title, Phone, Email FROM employees LIMIT 5 "

# %%
df4=pd.read_sql(query, db)
df4
# Out:
#   LastName FirstName                Title              Phone  \
# 0    Adams    Andrew      General Manager  +1 (780) 428-9482
# 1  Edwards     Nancy        Sales Manager  +1 (403) 262-3443
# 2  Peacock      Jane  Sales Support Agent  +1 (403) 262-3443
# 3     Park  Margaret  Sales Support Agent  +1 (403) 263-4423
# 4  Johnson     Steve  Sales Support Agent   1 (780) 836-9987
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
db=sql.connect('chinook.db')
cursor=db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' ;")
cursor.fetchall()
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
cursor.execute('SELECT COUNT(*) FROM sqlite_sequence')
cursor.fetchall()
# Out:
# [(10,)]

# %%
cursor.execute('PRAGMA table_info(sqlite_sequence)')
cursor.fetchall()
# Out:
# [(0, 'name', '', 0, None, 0), (1, 'seq', '', 0, None, 0)]

# %%
query="SELECT * FROM sqlite_sequence LIMIT 5"
df5=pd.read_sql(query, db)
df5
# Out:
#           name   seq
# 0       genres    25
# 1  media_types     5
# 2      artists   275
# 3       albums   347
# 4       tracks  3503
