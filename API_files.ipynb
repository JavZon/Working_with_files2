# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Working_with_files2/blob/main/API_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url='https://en.wikipedia.org/wiki/Saudi_Aramco'
data=pd.read_html(url)
len(data)
# Out:
# 13

# %%
data[3]
# Out:
#                            0  \
# 0  Major petroleum companies
# 1                Supermajors
# 2     National oil companies
# 3             Energy trading
# 4                     Others
# 5   Major services companies
# 6                     Others
#
#                                                    1
# 0  Supermajors BP Chevron Eni ExxonMobil Shell To...
# 1      BP Chevron Eni ExxonMobil Shell TotalEnergies
# 2  ADNOC ANCAP Bharat Petroleum CNOOC CNPC Ecopet...
# 3  Enron Glencore Gunvor Mercuria Naftiran Intert...
# 4  APA Cenovus Energy Compañía Española de Petról...
# 5  Amec Foster Wheeler Baker Hughes Cameron CGG C...
# 6  American Petroleum Institute Canadian Petroleu...

# %%
import json

json_string = '{"name": "John", "age": 30, "city": "New York"}'
python_obj = json.loads(json_string)

type(json_string)
# Out:
# str

# %%
python_file='I live in New York'
json_format=json.dumps(python_file)

type(json_format)
# Out:
# str

# %%
import requests

# %%
import pandas as pd
import json
r = requests.get("https://exchange-rates.abstractapi.com/v1/live/?api_key=5cf46373af5048f8b1d8906607d05ee7&base=USD&target=KRW")
r.json()
ind=1
pd.DataFrame(r.json())
# Out:
#     base  last_updated  exchange_rates
# KRW  USD    1704287700     1309.458596

# %%
import requests

# Making a GET request
response = requests.get('https://jsonplaceholder.typicode.com/posts/1')

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the content of the response
    print(response.json())
else:
    print(f"Error: {response.status_code}")
# Out:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
response.json()['body']
# Out:
# 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'

# %%
import pandas as pd
import requests
url="https://openlibrary.org/subjects/python.json?published_in=2015-2021"
response=requests.get(url)
if response.status_code ==200:
  data=response.json()
  df=pd.DataFrame(data['works'])
  print(df)
else:
  print(f"Error: {response.status_code}")
# Out:
#                    key                                              title  \
# 0   /works/OL17795703W                          Python for bioinformatics
# 1   /works/OL16976951W                                       Think Python
# 2   /works/OL15664278W                                  Head First Python
# 3    /works/OL6045694W                               Python in a Nutshell
# 4   /works/OL23330617W                        Making music with computers
# 5   /works/OL17422847W                           Python For Data Analysis
# 6   /works/OL21703042W                               Tour of Data Science
# 7   /works/OL21349037W  Introduction to Python for Science and Enginee...
# 8   /works/OL19548251W                                Python for Everyone
# 9   /works/OL19932156W                                      Fluent Python
# 10  /works/OL14940051W            Natural Language Processing With Python
# 11  /works/OL25187574W  Introduction to Modeling and Simulation with M...
#
# ...

# %%
df[['cover_id']]
# Out:
#      cover_id
# 0   8078288.0
# 1   7363360.0
# 2   6681113.0
# 3    389166.0
# 4         NaN
# 5   7548132.0
# 6         NaN
# 7         NaN
# 8   8514962.0
# 9   8743408.0
# 10  6296394.0
# 11        NaN

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Islamic_calendar')
df[54]
# Out:
#                                0  \
# 0  Mentioned idols (cult images)
# 1                  Of Israelites
# 2               Of Noah's people
# 3                     Of Quraysh
#
#                                                    1
# 0  'Ansāb Jibt and Ṭāghūt (False god)  Of Israeli...
# 1  Baʿal The ʿijl (golden calf statue) of Israelites
# 2                      Nasr Suwāʿ Wadd Yaghūth Yaʿūq
# 3                              Al-Lāt Al-ʿUzzā Manāt

# %%
url_link='https://exchange-rates.abstractapi.com/v1/live/?api_key=5cf46373af5048f8b1d8906607d05ee7&base=USD&target=KRW'
answer=requests.get(url_link)
answer.status_code # bizning link agar to'gri ishlasa status code 200 bo'ladi
answer.json()
df=pd.DataFrame(answer.json())
df
# Out:
#     base  last_updated  exchange_rates
# KRW  USD    1704287700     1309.458596
